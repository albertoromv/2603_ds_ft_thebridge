# %% [markdown]
# ![imagen](./img/ejercicios.png)

# %% [markdown]
# ## Ejercicio 1
# Dada la siguiente lista:
# > ```ejer_1 = [1,2,3,4,5]```
#
# Inviértela para que quede de la siguiente manera
# > ```ejer_1 = [5,4,3,2,1]```

# %%
ejer_1 = [1,2,3,4,5]
resul = list(reversed(ejer_1))
print(resul)

# %% [markdown]
# ## Ejercicio 2
# Eleva todos los elementos de la lista al cuadrado
# > ```ejer_2 = [1,2,3,4,5]```

# %%
ejer_2 = [1,2,3,4,5]
resul = []
for x in ejer_2:
    resul.append(x**2)
print(resul)
# Out:
# [1, 4, 9, 16, 25]

# %%
ejer_2 = [1,2,3,4,5]
for i, x in enumerate(ejer_2):
    x = x **2
    ejer_2[i]=x

print(ejer_2)
# Out:
# [1, 4, 9, 16, 25]

# %% [markdown]
# ## Ejercicio 3
# Crea una lista nueva con todas las combinaciones de las siguientes dos listas:
# > ```ejer_3_1 = ["Hola", "amigo"]```
# >
# > ```ejer_3_2 = ["Que", "tal"]```
#
# Obten el siguiente output:
#
# ['Hola Que', 'Hola tal', 'amigo Que', 'amigo tal']

# %%
ejer_3_1 = ["Hola", "amigo"]
ejer_3_2 = ["Que", "tal"]
resul = []

for i, x in enumerate(ejer_3_1):
    for j, y in enumerate(ejer_3_2):
        resul.append(' '.join([ejer_3_1[i], ejer_3_2[j]]))
print(resul)
# Out:
# ['Hola Que', 'Hola tal', 'amigo Que', 'amigo tal']

# %% [markdown]
# ## Ejercicio 4
# Dada la siguiente lista, encuentra el índice del valor 45 y sustitúyelo por el 0
# > ```ejer_4 = [20, 47, 19, 29, 45, 67, 78, 90]```

# %%
ejer_4 = [20, 47, 19, 29, 45, 67, 78, 90]

for i, x in enumerate(ejer_4):
    if x != 45:
        continue
    else:
        ejer_4[i] = 0
print(ejer_4)
# Out:
# [20, 47, 19, 29, 0, 67, 78, 90]

# %%
ejer_4 = [20, 47, 19, 29, 45, 67, 78, 90]

def sustuir(lista):
    return [0 if x == 45 else x for i, x in enumerate(lista)]

sustuir(ejer_4)
# Out:
# [20, 47, 19, 29, 0, 67, 78, 90]

# %% [markdown]
# ## Ejercicio 5
# Dada la siguiente lista, elimina todos los valores iguales a 3
# > ```ejer_5 = [3, 20, 3, 47, 19, 3, 29, 45, 67, 78, 90, 3, 3]```
#
# Consejo: No intentes eliminar elementos sobre la lista que estás iterando. Haz una copia con `ejer_5.copy()`.

# %%
ejer_5 = [3, 20, 3, 47, 19, 3, 29, 45, 67, 78, 90, 3, 3]

copia = ejer_5.copy()

for x in copia:
    if x == 3:
        copia.remove(x)
    for y in copia:
        if y == 3:
            copia.remove(y)

print(copia)
# Out:
# [20, 47, 19, 29, 45, 67, 78, 90]

# %%
ejer_5 = [3, 20, 3, 47, 19, 3, 29, 45, 67, 78, 90, 3, 3]

copia = ejer_5.copy()

for x in ejer_5:
    if x == 3:
        copia.remove(x)

print(copia)
# Out:
# [20, 47, 19, 29, 45, 67, 78, 90]

# %%
# ejer_5 = [3, 20, 3, 47, 19, 3, 29, 45, 67, 78, 90, 3, 3]
# numero = 3
# copia = ejer_5.copy()

# while numero in ejer_5:

# %% [markdown]
# ## Ejercicio 6
# 1. Crea una tupla con 3 elementos
# 2. Crea otra tupla con un elemento y comprueba su tipo
# 3. Crea una tupla con elementos de diferentes tipos
# 4. Imprime por pantalla el primer y ultimo elemento de la tupla del apartado 3. Usa `len` para el ultimo
# 5. Añade un elemento a la tupla del apartado 3.
# 6. Eliminar un elemento de la tupla del apartado 5, que se encuentre más o menos en la mitad.
# 7. Convierte la tupla del apartado 5 en una lista

# %%
tupla1 = (1, 2, 3)
tupla2 = (2)
print(f"Tipo de tupla2 {type(tupla2)}")
tupla3 = (3, '5', True)
print(f"4. {tupla3[0]}, {tupla3[len(tupla3)-1]}")
# tupla3[3] = False
# tupla3.pop(2)
print(list(tupla3))
# Out:
# Tipo de tupla2 <class 'int'>
# 4. 3, True
# [3, '5', True]

# %% [markdown]
# ## Ejercicio 7
# Concatena todos los elementos de la tupla en un unico string. Para ello utiliza el metodo `.join()` de los Strings
# > ```ejer_7 = ("cien", "cañones", "por", "banda")```
#
# Resultado: `cien cañones por banda`

# %%
ejer_7 = ("cien", "cañones", "por", "banda")

print(" ".join(list((ejer_7))))
# Out:
# cien cañones por banda

# %%
ejer_7 = ("cien", "cañones", "por", "banda")

print(' '.join(list(map(lambda x : x, ejer_7))))
# Out:
# cien cañones por banda

# %% [markdown]
# ## Ejercicio 8
# Obten el tercer elemento de la siguiente tupla, y el tercero empezando por la cola
# > ```ejer_8 = (3, 20, 3, 47, 19, 3, 29, 45, 67, 78, 90, 3, 3)```

# %%
ejer_8 = (3, 20, 3, 47, 19, 3, 29, 45, 67, 78, 90, 3, 3)

tercero = ejer_8[3]
tercero_2 = ejer_8[-3]

print(f"{tercero} y {tercero_2}")
# Out:
# 47 y 90

# %% [markdown]
# ## Ejercicio 9
# 1. ¿Cuántas veces se repite el 3 en la siguiente tupla?
# 2. Crea una tupla nueva con los elementos desde la posicion 5 a la 10.
# 3. ¿Cuántos elementos tiene la tupla `ejer_9`?
# > ```ejer_9 = (3, 20, 3, 47, 19, 3, 29, 45, 67, 78, 90, 3, 3, 5, 2, 4, 7, 9, 4, 2, 4, 3, 3, 4, 6, 7)```

# %%
ejer_9 = (3, 20, 3, 47, 19, 3, 29, 45, 67, 78, 90, 3, 3, 5, 2, 4, 7, 9, 4, 2, 4, 3, 3, 4, 6, 7)
counter = 0
lista = []


for x in ejer_9:
    if x == 3:
        counter += 1
print(counter)

for i, x in enumerate(ejer_9):
    if i > 5 and i < 10:
        lista.append(x)
print(tuple(lista))
print(len(ejer_9))
# Out:
# 7
# (29, 45, 67, 78)
# 26

# %% [markdown]
# ## Ejercicio 10
# Comprueba si el numero 60 esta en la tupla del ejercicio 9

# %%
ejer_9 = (3, 20, 3, 47, 19, 3, 29, 45, 67, 78, 90, 3, 3, 5, 2, 4, 7, 9, 4, 2, 4, 3, 3, 4, 6, 7)
counter = 0
for x in ejer_9:
    if x == 60:
        counter += 1
print(f"El elemento 60 aparece {counter} veces en la tupla")
# Out:
# El elemento 60 aparece 0 veces en la tupla

# %% [markdown]
# ## Ejercicio 11
# 1. Convierte la tupla del apartado 10 en una lista
# 2. Convierte la tupla del apartado 10 en un set
# 3. Convierte la tupla del apartado 10 en un diccionario. Usa también los indices

# %%
ejer_9 = (3, 20, 3, 47, 19, 3, 29, 45, 67, 78, 90, 3, 3, 5, 2, 4, 7, 9, 4, 2, 4, 3, 3, 4, 6, 7)

lista = list(ejer_9)
set_1 = set(ejer_9)
dic_1 = {}

for i,x in enumerate(ejer_9):
    dic_1[i] = x

print(f"{lista} \n {set_1} \n {dic_1}")
# Out:
# [3, 20, 3, 47, 19, 3, 29, 45, 67, 78, 90, 3, 3, 5, 2, 4, 7, 9, 4, 2, 4, 3, 3, 4, 6, 7]
#  {2, 3, 67, 5, 4, 7, 6, 9, 45, 78, 47, 19, 20, 90, 29}
#  {0: 3, 1: 20, 2: 3, 3: 47, 4: 19, 5: 3, 6: 29, 7: 45, 8: 67, 9: 78, 10: 90, 11: 3, 12: 3, 13: 5, 14: 2, 15: 4, 16: 7, 17: 9, 18: 4, 19: 2, 20: 4, 21: 3, 22: 3, 23: 4, 24: 6, 25: 7}

# %% [markdown]
# ## Ejercicio 12
# Convierte la siguiente tupla en un diccionario
# > ```ejer_12 = [("x", 1), ("x", 2), ("x", 3), ("y", 1), ("y", 2), ("z", 1)]```
#
# TIP: Puedes usar dos variables de control en un bucle `for`. Una por cada valor de las tuplas.

# %%
ejer_12 = [("x", 1), ("x", 2), ("x", 3), ("y", 1), ("y", 2), ("z", 1)]
dic_2 = dict(ejer_12)

print(dic_2)
# Out:
# {'x': 3, 'y': 2, 'z': 1}

# %% [markdown]
# ## Ejercicio 13
# 1. Crea una lista ordenada ascendente con las claves del diccionario
# 2. Crea otra lista ordenada descendente con los valores
# 3. Añade una nueva clave/valor
# 4. Busca la clave 2 dentro del diccionario
# 5. Itera la clave y el valor del diccionario con un unico for
# > ```ejer_13 = {4:78, 2:98, 8:234, 5:29}```

# %%
ejer_13 = {4:78, 2:98, 8:234, 5:29}

lista_1 = list(ejer_13)

print(sorted(lista_1))

lista_2 = list(ejer_13.values())
print(sorted(lista_2, reverse= True))

ejer_13[7] = 133

print(ejer_13[2])

for clave, valor in ejer_13.items():
    print(f"{clave}: {valor}", end=' | ')
# Out:
# [2, 4, 5, 8]
# [234, 98, 78, 29]
# 98
# 4: 78 | 2: 98 | 8: 234 | 5: 29 | 7: 133 |

# %% [markdown]
# ## Ejercicio 14
# Junta ambos diccionarios. Para ello, utiliza `update`
# > ```ejer_14_1 = {1: 11, 2: 22}```
# >
# > ```ejer_14_2 = {3: 33, 4: 44}```

# %%
ejer_14_1 = {1: 11, 2: 22}

ejer_14_2 = {3: 33, 4: 44}

ejer_14_1.update(ejer_14_2)

print(ejer_14_1)
# Out:
# {1: 11, 2: 22, 3: 33, 4: 44}

# %% [markdown]
# ## Ejercicio 15
# Suma todos los valores del dicionario
# > ```ejer_15 = {1: 11, 2: 22, 3: 33, 4: 44, 5: 55}```

# %%
ejer_15 = {1: 11, 2: 22, 3: 33, 4: 44, 5: 55}

print(sum(ejer_15.values()))
# Out:
# 165

# %% [markdown]
# ## Ejercicio 16
# Multiplica todos los valores del diccionario
# > ```ejer_16 = {1: 11, 2: 22, 3: 33, 4: 44, 5: 55}```

# %%
ejer_16 = {1: 11, 2: 22, 3: 33, 4: 44, 5: 55}

list(map(lambda x: x * x, ejer_16.values()))
# Out:
# [121, 484, 1089, 1936, 3025]

# %%
multi = 1

for value in ejer_16.values():
    multi = multi * value

print(multi)
# Out:
# 19326120

# %% [markdown]
# ## Ejercicio 17
# 1. Crea un set de tres elementos
# 2. Añade un cuarto
# 3. Elimina el utlimo elemento añadido
# 4. Elimina el elemento 10, si está presente. Usa `discard()`

# %%
set_1 = {13, '13', True}

print(set_1)

set_1.add('False')

print(set_1)

set_1.pop()

print(set_1)

set_1.discard(10)

print(set_1)
# Out:
# {'13', True, 13}
# {'13', True, 'False', 13}
# {True, 'False', 13}
# {True, 'False', 13}
